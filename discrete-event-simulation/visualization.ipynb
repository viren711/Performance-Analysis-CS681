# %%
pip install ipykernel
# Out:
# Requirement already satisfied: ipykernel in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (7.2.0)
# Requirement already satisfied: comm>=0.1.1 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from ipykernel) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from ipykernel) (9.11.0)
# Requirement already satisfied: jupyter-client>=8.8.0 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from ipykernel) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from ipykernel) (26.0)
# Requirement already satisfied: psutil>=5.7 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from ipykernel) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from ipykernel) (6.5.5)
# Requirement already satisfied: traitlets>=5.4.0 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: decorator>=5.1.0 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: pexpect>4.6 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from jupyter-client>=8.8.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel) (4.9.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from pexpect>4.6->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.6.0)
# Requirement already satisfied: six>=1.5 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.8.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas matplotlib
# Out:
# Collecting pandas
#   Using cached pandas-3.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Using cached numpy-2.4.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.5/117.5 kB 4.2 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: packaging>=20.0 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-12.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in /home/viren/IITB/Courses/SEM 2/CS 681/Performance-Analysis-CS681/env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-3.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
# Using cached matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
# Using cached contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 10.4 MB/s eta 0:00:0000:0100:01
# Using cached kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
# Using cached numpy-2.4.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
# Using cached pillow-12.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, pandas, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.8 numpy-2.4.3 pandas-3.0.1 pillow-12.1.1 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
df = pd.read_csv('../discrete-event-simulation/users_results.csv')

# Create the plot with proper labels and grid
# plt.figure(figsize=(12, 7))
plt.plot(df['users'], df['throughput'], 'o-', linewidth=3, markersize=10, color='darkblue', label='Throughput')

# Add labels and title
plt.xlabel('Number of Users', fontsize=14)
plt.ylabel('Throughput (req/s)', fontsize=14)
plt.title('System Throughput vs Users', fontsize=16, fontweight='bold', pad=20)

# Customize grid
plt.grid(True, alpha=0.4, linestyle='--', linewidth=1)
plt.minorticks_on()
# plt.grid(which='major', alpha=0.4, linestyle='--', linewidth=1)
# plt.grid(which='minor', alpha=0.2, linestyle=':', linewidth=0.8)

# Set proper ticks
plt.xticks(df['users'])
# plt.yticks(range(0, int(df['throughput'].max()) + 1, 1))

# Add legend
plt.legend(loc='best', fontsize=12)

# Improve layout
plt.tight_layout()
# plt.savefig('labeled_throughput.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# plt.figure(figsize=(10, 6))
plt.plot(df['users'], df['utilization']*100, 'o-', linewidth=2.5, markersize=8, color='red')
plt.xlabel('Number of Users', fontsize=12,  )
plt.ylabel('CPU Utilization (%)', fontsize=12)
plt.title('CPU Utilization vs Users', fontweight='bold')
plt.grid(True, alpha=0.3)
plt.xticks(df['users'])
plt.tight_layout()
plt.savefig('cpu_utilization.png', dpi=300, bbox_inches='tight')
plt.tight_layout()
# plt.savefig('labeled_throughput.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# plt.figure(figsize=(10, 6))
plt.plot(df['users'], df['mean_response'], 's-', linewidth=2.5, markersize=8, 
         color='green')
plt.xlabel('Number of Users', fontsize=12)
plt.ylabel('Response Time (seconds)', fontsize=12)
plt.title('Response Time vs Users', fontweight='bold')
plt.grid(True, alpha=0.3)
plt.xticks(df['users'])
plt.legend()
plt.tight_layout()
plt.show
# Out:
# /tmp/ipykernel_23628/1013373954.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(df['users'], df['drop'], 'D-', linewidth=2.5, markersize=8, 
         color='orange', label='Request Drop Fraction')
plt.xlabel('Number of Users', fontsize=12)
plt.ylabel('Drop Fraction', fontsize=12)
plt.title('Request Drop Rate vs Users', fontweight='bold')
plt.grid(True, alpha=0.3)
plt.xticks(df['users'])
plt.ylim(0, 0.01) # Zoom to show zero line clearly
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.plot(df['throughput'], df['utilization']*100, 'o-', linewidth=2.5, markersize=8, 
         color='purple', label='CPU Utilization')
plt.xlabel('Throughput', fontsize=12)
plt.ylabel('CPU Utilization (%)', fontsize=12)
plt.title('CPU Utilization vs Throughput', fontweight='bold')
plt.grid(True, alpha=0.3)
plt.ylim(0, 100)  # Y-axis starts at 0
plt.legend()
plt.tight_layout()
# plt.savefig('cpu_vs_throughput.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
df = pd.read_csv("../discrete-event-simulation/ctxx_results.csv")

plt.figure(figsize=(10, 6))
plt.plot(df['ctxswitch'], df['throughput'], 'o-', linewidth=2.5, markersize=8, 
         color='darkred', label='Throughput')
plt.xlabel('Context Switch Time (seconds)', fontsize=12)
plt.ylabel('Throughput (req/s)', fontsize=12)
plt.title('Throughput vs Context Switch Time', fontweight='bold')
plt.grid(True, alpha=0.3)
# plt.ylim(4, 5.1)
plt.legend()
plt.tight_layout()
plt.show()  # Display only, no save

# %%
plt.plot(df['ctxswitch'], df['response'], 's-', linewidth=2.5, markersize=8, 
         color='darkgreen', label='Response Time')
plt.xlabel('Context Switch Time (seconds)', fontsize=12)
plt.ylabel('Response Time (seconds)', fontsize=12)
plt.title('Response Time vs Context Switch Time', fontweight='bold')
plt.grid(True, alpha=0.3)
# plt.ylim(1.7, 2.1)
plt.legend()
plt.tight_layout()
plt.show()  # Display only
